# %% [markdown]
# <a href="https://colab.research.google.com/github/mohanraju2002/PYTHON_PROJECTS/blob/main/HANDCRICKET.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
print("-------------------------------------------------------------------------------")
print("*****************  WELCOME TO CRICKET *******************")
print("-------------------------------------------------------------------------------")
count=0
comp=0
toss=input("what is your choice (heads//tails):")
ee=("heads","tails")
bb=random.choice(ee)
print(bb)
if bb==toss:
    print("*********    u won the toss   ************")
    opt=input("select batting or bowling:")
    if opt=="bat" :
        run = int(input("enter the  your runs:"))
        b = random.randint(1, 2)
        print("computer runs:", b)
        if run!=b:

            count = count + run
            print(count)
        else:
            print(0)
            r="**********  OUT ******************"
        while run!=b:
            run = int(input("enter the  your runs:"))

            b = random.randint(1, 6)
            print("computer runs:", b)

            if run!=b:
                count=count+run
                print(count)
            if b==run:
                print(r)
                print("..........................................................................")
                print("your final runs is:",count)
                print("...........................................................................")
    opt = input("ARE U ready to bowl or not:")

    if opt=="bowl" or opt=="ready":
        run = int(input("enter the  your runs:"))
        b = random.randint(1, 6)
        print("computer runs:", b)
        comp = comp + b
        print(comp)
        r = "**********  COMPUTER OUT ******************"
        while run != b:
            run = int(input("enter the  your runs:"))
            b = random.randint(1, 6)
            print("computer runs:", b)
            if run != b:
                comp = comp + b
                print(comp)
            if b == run:
                print(r)
                print("...........................................................................")
                print("computer runs is:", comp)
                print("............................................................................")
    if count > comp:
         print("******************   YOU WIN **************************************")
    elif comp > count:
        print("********************* COMPUTER WIN ********************************** ")

    else:
        print("*******************  comp win  ***********************************")
